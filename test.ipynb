# %%
import torch
from vit import ViT

model = ViT(
    img_size=224,
    patch_size=16,
    in_ch=3,
    num_classes=1000,
    embed_dim=768,
    depth=2,
    num_heads=12,
    mlp_ratio=4,
    drop_rate=0.0,
)

# n of pathes 
img = torch.randn(1, 3, 224, 224)
pred = model(img)
# Out:
# > /home/gabbo/Documents/Vision_transformer_pytorch/vit.py(50)forward()
#      49         import ipdb; ipdb.set_trace()
# ---> 50         attn = self.attn_dropout(attn)
#      51
#
# ipdb> attn.shape
# torch.Size([1, 12, 197, 197])

# %%
pred
# Out:
# tensor([[-6.0154e-01, -8.1138e-01, -1.1754e-01,  1.0516e+00, -3.0080e-01,
#           1.0504e+00, -3.6600e-01, -1.7091e-01,  2.0277e-01,  3.0760e-01,
#           5.8091e-01,  9.5504e-01, -1.3769e-01,  3.6529e-01,  9.2172e-01,
#          -5.6902e-02, -2.2257e-01, -7.6135e-01,  1.3141e+00,  2.8917e-01,
#           3.8936e-01, -6.4729e-01,  1.4221e-01, -6.1570e-01, -3.9005e-01,
#           5.3825e-02, -2.2589e-01, -7.5671e-01,  3.4478e-02,  4.2391e-01,
#          -9.8333e-01, -5.3038e-01, -2.5306e-02,  5.9758e-01, -6.8697e-01,
#           1.7811e-01,  2.8337e-01, -2.9689e-01, -9.0446e-01,  7.5236e-01,
#          -6.2659e-01, -3.1253e-01,  1.1645e-01, -2.8816e-02, -2.4923e-02,
#          -4.4359e-01, -3.1175e-01, -5.0154e-01, -5.5045e-01,  5.9638e-01,
#           2.1528e-01, -9.3820e-01,  3.7691e-01, -4.3072e-02, -1.4843e-01,
#           3.9002e-01, -7.5542e-01, -4.5130e-01, -2.9964e-01,  1.6110e-01,
#           3.8650e-01,  9.9397e-02,  1.3380e-01,  2.9511e-01,  8.8036e-01,
# ...
